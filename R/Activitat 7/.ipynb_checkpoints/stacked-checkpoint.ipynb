# %% [markdown]
# <!--Header-->
# <div>
#     <div class="row" style="color: #4D4D4D;font-size: 15px;padding-bottom: 20px">
#         <div class="col-md-7">
#             <img src="http://materials.cv.uoc.edu/cdocent/common/img/logo-uoc.png" alt="Logo UOC" class="img-responsive" style="margin:20px 0px 0px">
#         </div>
#         <div class="col-md-5">
#             <h1 style="margin:15px 0px 0px;font-size: 40px;">Combinació de classificadors: Stacking</h1>
#             <div style="text-align:left;margin-top: 5px;"></div>
#         </div>
#     </div>
#     <div class="row" style="background: #FCB517;padding: 10px 20px;">
#         <div class="col-md-6">
#             <div>PID_00233252</div>
#         </div>
#         <div class="col-md-6">
#             <div style="text-align:right;">Autor: Xavier Duran Albareda <span style="margin-left: 30px;">Coordinació: Julià Minguillón</span></div>
#         </div>
#     </div>
# </div>
# <!--/Header-->

# %% [markdown]
# ## Introducció

# %% [markdown]
# En aquest exemple, adaptat del llibre [Minería de datos, algoritmos y modelos](http://oer.uoc.edu/libroMD/), es mostra com generar un classificador arbre de decisió i com millorar-lo amb la tècnica de [Stacking](http://blog.kaggle.com/2016/12/27/a-kagglers-guide-to-model-stacking-in-practice/).
#
# Les dades analitzades corresponen al _dataset_ [Breast Cancer Wisconsin (Diagnostic) Data Set](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data).

# %% [markdown]
# ### Instal·lar els paquets necessaris en cas de no tenir-los

# %%
if(!require(rpart)){
    install.packages('rpart',repos='http://cran.es.r-project.org')
    require(rpart)
}
if(!require(caret)){
    install.packages('caret',repos='http://cran.es.r-project.org')
    require(caret)
}
if(!require(randomForest)){
    install.packages('randomForest',repos='http://cran.es.r-project.org')
    require(ramdomForest)
}
if(!require(caretEnsemble)){
    install.packages('caretEnsemble',repos='http://cran.es.r-project.org')
    require(caretEnsemble)
}
if(!require(C50)){
    install.packages('C50',repos='http://cran.es.r-project.org')
    require(C50)
}
if(!require(plyr)){
    install.packages('plyr',repos='http://cran.es.r-project.org')
    require(plyr)
}
if(!require(kernlab)){
    install.packages('kernlab',repos='http://cran.es.r-project.org')
    require(kernlab)
}
if(!require(nnet)){
    install.packages('nnet',repos='http://cran.es.r-project.org')
    require(nnet)
}
set.seed(17)
# Out:
# Loading required package: rpart
# Loading required package: caret
# Loading required package: lattice
# Loading required package: ggplot2
# Loading required package: randomForest
# randomForest 4.6-14
# Type rfNews() to see new features/changes/bug fixes.
#
# Attaching package: ‘randomForest’
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
# Loading required package: caretEnsemble
#
# Attaching package: ‘caretEnsemble’
#
# The following object is masked from ‘package:ggplot2’:
#
#     autoplot
#
# Loading required package: C50
# Loading required package: plyr
# Loading required package: kernlab
#
# Attaching package: ‘kernlab’
#
# The following object is masked from ‘package:ggplot2’:
#
#     alpha
#
# Loading required package: nnet

# %% [markdown]
# ### Càrrega de les dades

# %%
wdbc=read.table(
    url("https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data"),
    sep=",",
    header=FALSE
)
dim(wdbc)
dataset <- wdbc[,(2:32)]
# Out:
# [1] 569  32

# %% [markdown]
# ### Paràmetres de creació del model
#
# Utilitzarem la mètrica _Accuracy_ que mesura el percentatge d'instàncies correctes sobre el total. Farem la validació creuada o _crossvalidation_ amb 10 _folds_.

# %%
metric <- "Accuracy"
control <- trainControl(method="repeatedcv", number=10, repeats=3, savePredictions="all", classProbs=TRUE)
algorithmList <- c('nnet', 'rpart', 'C5.0', 'knn', 'svmRadial')

# %% [markdown]
# ### Creem el nivell 0

# %%
models <- caretList(V2~., data=dataset, trControl=control, metric=metric, methodList=algorithmList)
# Out:
# Warning message in trControlCheck(x = trControl, y = target):
# “indexes not defined in trControl.  Attempting to set them ourselves, so each model in the ensemble will have the same resampling indexes.”
# # weights:  33
# initial  value 357.697663
# final  value 338.205383
# converged
# # weights:  97
# initial  value 359.324078
# final  value 338.205383
# converged
# # weights:  161
# initial  value 354.226379
# iter  10 value 336.232656
# iter  20 value 336.226690
# iter  20 value 336.226687
# iter  20 value 336.226687
# final  value 336.226687
# converged
# # weights:  33
# initial  value 496.244406
# iter  10 value 338.231892
# final  value 338.218999
# converged
# # weights:  97
# initial  value 344.568397
# iter  10 value 339.285052
# iter  20 value 338.222954
# iter  30 value 338.215062
# iter  40 value 338.214638
# iter  50 value 338.213314
# iter  60 value 338.213094
# final  value 338.212515
# converged
# # weights:  161
# initial  value 340.025837
# iter  10 value 232.871866
# iter  20 value 143.760867
# iter  30 value 125.726319
# iter  40 value 116.589871
# iter  50 value 112.502566
# iter  60 value 111.342301
# iter  70 value 79.429827
# iter  80 value 63.345618
# iter  90 value 51.058783
# iter 100 value 49.849649
# final  value 49.849649
# stopped after 100 iterations
# # weights:  33
# initial  value 366.766045
# final  value 338.205961
# converged
# # weights:  97
# initial  value 434.164528
# final  value 338.207167
# converged
# # weights:  161
# initial  value 379.572196
# iter  10 value 181.808871
# iter  20 value 144.891361
# iter  30 value 144.780642
# iter  40 value 144.769395
# iter  50 value 144.762251
# iter  60 value 144.756875
# iter  70 value 144.752290
# iter  80 value 129.406870
# iter  90 value 117.931860
# iter 100 value 104.174977
# final  value 104.174977
# stopped after 100 iterations
# # weights:  33
# initial  value 347.333117
# final  value 337.217686
# converged
# # weights:  97
# initial  value 484.929283
# final  value 337.217686
# converged
# # weights:  161
# initial  value 417.099297
# final  value 337.217686
# converged
# # weights:  33
# initial  value 339.451768
# iter  10 value 233.102672
# iter  20 value 174.041971
# iter  30 value 158.463260
# iter  40 value 147.353468
# iter  50 value 131.829422
# iter  60 value 112.265195
# iter  70 value 61.785103
# iter  80 value 50.959999
# iter  90 value 48.699383
# final  value 48.698037
# converged
# # weights:  97
# initial  value 375.566110
# iter  10 value 336.913217
# iter  20 value 140.427840
# iter  30 value 133.092065
# iter  40 value 125.464830
# iter  50 value 100.233574
# iter  60 value 70.667794
# iter  70 value 57.811103
# iter  80 value 51.494604
# iter  90 value 42.016420
# iter 100 value 37.887278
# final  value 37.887278
# stopped after 100 iterations
# # weights:  161
# initial  value 372.853873
# iter  10 value 337.324515
# iter  20 value 303.716820
# iter  30 value 212.681360
# iter  40 value 144.487571
# iter  50 value 54.149447
# iter  60 value 43.716349
# iter  70 value 36.698836
# iter  80 value 35.971053
# iter  90 value 35.876200
# iter 100 value 35.863727
# final  value 35.863727
# stopped after 100 iterations
# # weights:  33
# initial  value 374.411460
# iter  10 value 337.231603
# iter  20 value 337.217860
# final  value 337.217705
# converged
# # weights:  97
# initial  value 338.245136
# final  value 337.219263
# converged
# # weights:  161
# initial  value 343.229997
# final  value 337.222992
# converged
# # weights:  33
# initial  value 356.693155
# iter  10 value 314.261356
# iter  20 value 226.638184
# iter  30 value 148.398293
# iter  40 value 131.497935
# iter  50 value 127.220051
# iter  60 value 127.213559
# final  value 127.212636
# converged
# # weights:  97
# initial  value 354.856393
# iter  10 value 191.168537
# final  value 190.142118
# converged
# # weights:  161
# initial  value 361.840487
# iter  10 value 220.100312
# iter  20 value 145.422833
# iter  30 value 144.101450
# iter  40 value 139.792116
# iter  50 value 139.513951
# iter  60 value 139.509541
# final  value 139.509537
# converged
# # weights:  33
# initial  value 399.651686
# iter  10 value 334.973744
# iter  20 value 312.108812
# iter  30 value 212.454172
# iter  40 value 154.227081
# iter  50 value 125.523923
# iter  60 value 119.789727
# iter  70 value 93.814055
# iter  80 value 63.137354
# iter  90 value 56.333293
# iter 100 value 55.261462
# final  value 55.261462
# stopped after 100 iterations
# # weights:  97
# initial  value 340.072835
# iter  10 value 281.788154
# iter  20 value 159.148569
# iter  30 value 141.357644
# iter  40 value 122.070133
# iter  50 value 89.989587
# iter  60 value 55.987747
# iter  70 value 52.370306
# iter  80 value 50.940766
# iter  90 value 44.930976
# iter 100 value 42.552635
# final  value 42.552635
# stopped after 100 iterations
# # weights:  161
# initial  value 437.890279
# iter  10 value 319.448122
# iter  20 value 169.711222
# iter  30 value 149.876915
# iter  40 value 145.593829
# iter  50 value 133.464224
# iter  60 value 126.215520
# iter  70 value 104.954166
# iter  80 value 85.805920
# iter  90 value 73.337567
# iter 100 value 62.080073
# final  value 62.080073
# stopped after 100 iterations
# # weights:  33
# initial  value 342.865960
# final  value 338.206099
# converged
# # weights:  97
# initial  value 358.157283
# final  value 338.207819
# converged
# # weights:  161
# initial  value 372.353159
# iter  10 value 337.234731
# final  value 337.230018
# converged
# # weights:  33
# initial  value 324.884464
# iter  10 value 167.781626
# iter  20 value 127.420390
# iter  30 value 105.534702
# iter  40 value 99.277152
# iter  50 value 98.957944
# iter  60 value 95.792439
# iter  70 value 93.803981
# iter  80 value 90.521415
# iter  90 value 88.897711
# iter 100 value 87.635090
# final  value 87.635090
# stopped after 100 iterations
# # weights:  97
# initial  value 322.238160
# iter  10 value 169.882081
# iter  20 value 125.442704
# iter  30 value 107.301157
# iter  40 value 95.715184
# iter  50 value 91.403150
# iter  60 value 88.692285
# iter  70 value 86.525193
# iter  80 value 85.300617
# iter  90 value 83.652756
# iter 100 value 82.158112
# final  value 82.158112
# stopped after 100 iterations
# # weights:  161
# initial  value 416.255994
# final  value 338.205383
# converged
# # weights:  33
# initial  value 467.123355
# iter  10 value 338.219330
# iter  10 value 338.219327
# iter  10 value 338.219327
# final  value 338.219327
# converged
# # weights:  97
# initial  value 348.871796
# iter  10 value 338.264327
# iter  20 value 337.259356
# iter  30 value 202.072910
# iter  40 value 146.437990
# iter  50 value 124.724465
# iter  60 value 109.318712
# iter  70 value 103.192506
# iter  80 value 94.067472
# iter  90 value 91.313790
# iter 100 value 88.300383
# final  value 88.300383
# stopped after 100 iterations
# # weights:  161
# initial  value 374.949889
# iter  10 value 325.099746
# iter  20 value 176.964405
# iter  30 value 144.058800
# iter  40 value 123.054485
# iter  50 value 92.615890
# iter  60 value 74.481214
# iter  70 value 64.970486
# iter  80 value 49.894723
# iter  90 value 46.242557
# iter 100 value 42.676210
# final  value 42.676210
# stopped after 100 iterations
# # weights:  33
# initial  value 345.941220
# final  value 338.205926
# converged
# # weights:  97
# initial  value 453.114139
# final  value 338.211183
# converged
# # weights:  161
# initial  value 358.764310
# iter  10 value 185.149558
# iter  20 value 154.753023
# iter  30 value 151.649932
# iter  40 value 151.539324
# iter  50 value 149.625401
# iter  60 value 116.931657
# iter  70 value 113.261840
# iter  80 value 97.467917
# iter  90 value 90.805057
# iter 100 value 87.908833
# final  value 87.908833
# stopped after 100 iterations
# # weights:  33
# initial  value 372.724266
# final  value 338.671686
# converged
# # weights:  97
# initial  value 373.761172
# final  value 338.671686
# converged
# # weights:  161
# initial  value 391.841943
# final  value 338.671686
# converged
# # weights:  33
# initial  value 382.240688
# iter  10 value 338.228423
# iter  20 value 302.231453
# iter  30 value 155.215262
# iter  40 value 121.139574
# iter  50 value 111.732480
# iter  60 value 97.873693
# iter  70 value 72.666750
# iter  80 value 54.387453
# iter  90 value 54.029104
# final  value 54.028635
# converged
# # weights:  97
# initial  value 366.693832
# iter  10 value 286.986278
# iter  20 value 168.523350
# iter  30 value 151.432297
# iter  40 value 142.743414
# iter  50 value 116.737901
# iter  60 value 73.652763
# iter  70 value 61.370276
# iter  80 value 51.616707
# iter  90 value 47.946319
# iter 100 value 46.934919
# final  value 46.934919
# stopped after 100 iterations
# # weights:  161
# initial  value 364.263286
# iter  10 value 342.811967
# iter  20 value 338.724292
# iter  30 value 338.705450
# iter  40 value 338.699068
# iter  50 value 338.688331
# iter  60 value 338.687692
# iter  70 value 338.686633
# iter  80 value 338.685344
# iter  90 value 338.681789
# iter 100 value 248.869451
# final  value 248.869451
# stopped after 100 iterations
# # weights:  33
# initial  value 371.304466
# final  value 338.675483
# converged
# # weights:  97
# initial  value 400.181964
# final  value 338.673358
# converged
# # weights:  161
# initial  value 390.294333
# final  value 338.674440
# converged
# # weights:  33
# initial  value 503.242801
# final  value 338.205383
# converged
# # weights:  97
# initial  value 496.685481
# final  value 338.205383
# converged
# # weights:  161
# initial  value 342.258474
# final  value 338.205383
# converged
# # weights:  33
# initial  value 397.124199
# iter  10 value 338.224152
# final  value 338.218999
# converged
# # weights:  97
# initial  value 421.345714
# iter  10 value 337.984713
# iter  20 value 302.985653
# iter  30 value 183.627730
# iter  40 value 144.658660
# iter  50 value 135.771151
# iter  60 value 118.751635
# iter  70 value 81.757594
# iter  80 value 51.431543
# iter  90 value 50.122749
# final  value 50.122713
# converged
# # weights:  161
# initial  value 359.545710
# iter  10 value 276.989039
# iter  20 value 147.673273
# iter  30 value 133.073485
# iter  40 value 104.484119
# iter  50 value 69.903999
# iter  60 value 50.631363
# iter  70 value 50.021902
# iter  80 value 49.018286
# iter  90 value 44.861183
# iter 100 value 43.532816
# final  value 43.532816
# stopped after 100 iterations
# # weights:  33
# initial  value 350.679251
# final  value 338.205940
# converged
# # weights:  97
# initial  value 419.918170
# final  value 338.206895
# converged
# # weights:  161
# initial  value 350.053316
# final  value 338.208066
# converged
# # weights:  33
# initial  value 387.962266
# final  value 338.205383
# converged
# # weights:  97
# initial  value 341.739413
# final  value 338.205383
# converged
# # weights:  161
# initial  value 353.118538
# final  value 338.205383
# converged
# # weights:  33
# initial  value 338.210353
# iter  10 value 275.524598
# iter  20 value 172.059163
# iter  30 value 133.318172
# iter  40 value 123.317233
# iter  50 value 121.329113
# iter  60 value 115.568526
# iter  70 value 82.878640
# iter  80 value 53.275314
# iter  90 value 51.812651
# iter 100 value 50.157043
# final  value 50.157043
# stopped after 100 iterations
# # weights:  97
# initial  value 359.120543
# iter  10 value 338.215611
# iter  20 value 334.309619
# iter  30 value 197.074665
# iter  40 value 146.156112
# iter  50 value 142.360047
# iter  60 value 126.308424
# iter  70 value 113.840700
# iter  80 value 104.931803
# iter  90 value 87.987442
# iter 100 value 71.423681
# final  value 71.423681
# stopped after 100 iterations
# # weights:  161
# initial  value 348.525068
# iter  10 value 205.297742
# iter  20 value 175.260348
# iter  30 value 157.888854
# iter  40 value 155.432224
# iter  50 value 147.898975
# iter  60 value 96.007511
# iter  70 value 62.345902
# iter  80 value 47.374147
# iter  90 value 45.653479
# iter 100 value 45.647001
# final  value 45.647001
# stopped after 100 iterations
# # weights:  33
# initial  value 512.229911
# final  value 338.206851
# converged
# # weights:  97
# initial  value 404.266355
# final  value 338.207184
# converged
# # weights:  161
# initial  value 340.922409
# iter  10 value 183.747154
# iter  20 value 154.302348
# iter  30 value 141.615260
# iter  40 value 91.199719
# iter  50 value 84.407474
# iter  60 value 71.338983
# iter  70 value 70.439142
# iter  80 value 65.362302
# iter  90 value 62.683830
# iter 100 value 58.730580
# final  value 58.730580
# stopped after 100 iterations
# # weights:  33
# initial  value 488.474673
# final  value 337.682037
# converged
# # weights:  97
# initial  value 357.450826
# final  value 337.682037
# converged
# # weights:  161
# initial  value 406.357977
# final  value 337.682037
# converged
# # weights:  33
# initial  value 350.701982
# iter  10 value 335.491739
# iter  20 value 212.916715
# iter  30 value 144.314512
# iter  40 value 116.297966
# iter  50 value 84.059060
# iter  60 value 56.201483
# iter  70 value 54.026574
# final  value 54.025752
# converged
# # weights:  97
# initial  value 375.169046
# iter  10 value 338.105126
# iter  20 value 338.069169
# iter  30 value 337.762705
# iter  40 value 198.808320
# iter  50 value 145.747606
# iter  60 value 124.398342
# iter  70 value 71.767196
# iter  80 value 54.336119
# iter  90 value 49.009389
# iter 100 value 47.654676
# final  value 47.654676
# stopped after 100 iterations
# # weights:  161
# initial  value 341.547004
# iter  10 value 337.332518
# iter  20 value 162.643557
# iter  30 value 158.999142
# iter  40 value 145.147524
# iter  50 value 122.969464
# iter  60 value 111.829652
# iter  70 value 100.366206
# iter  80 value 86.890067
# iter  90 value 63.434049
# iter 100 value 53.900266
# final  value 53.900266
# stopped after 100 iterations
# # weights:  33
# initial  value 364.989365
# final  value 337.683629
# converged
# # weights:  97
# initial  value 370.821967
# iter  10 value 157.769067
# iter  20 value 130.428383
# iter  30 value 128.997165
# iter  40 value 126.805815
# iter  50 value 126.692519
# iter  60 value 126.683284
# iter  70 value 113.850186
# iter  80 value 110.180191
# iter  90 value 110.169119
# iter 100 value 110.168092
# final  value 110.168092
# stopped after 100 iterations
# # weights:  161
# initial  value 425.462281
# iter  10 value 186.550757
# iter  20 value 185.716567
# iter  30 value 173.507483
# iter  40 value 166.031301
# iter  50 value 155.000124
# iter  60 value 151.968790
# iter  70 value 151.964333
# iter  80 value 151.845115
# iter  90 value 131.640873
# iter 100 value 129.794875
# final  value 129.794875
# stopped after 100 iterations
# # weights:  33
# initial  value 384.889592
# final  value 338.205383
# converged
# # weights:  97
# initial  value 340.618131
# final  value 338.205383
# converged
# # weights:  161
# initial  value 353.280986
# iter  10 value 161.997902
# iter  20 value 139.443012
# iter  30 value 134.853236
# iter  40 value 134.799736
# iter  50 value 134.798777
# final  value 134.798742
# converged
# # weights:  33
# initial  value 341.812992
# iter  10 value 338.218999
# iter  10 value 338.218999
# iter  10 value 338.218999
# final  value 338.218999
# converged
# # weights:  97
# initial  value 350.495386
# iter  10 value 338.220319
# iter  20 value 338.219411
# iter  30 value 338.213222
# iter  40 value 338.212521
# iter  40 value 338.212520
# iter  40 value 338.212520
# final  value 338.212520
# converged
# # weights:  161
# initial  value 344.172358
# iter  10 value 171.009718
# iter  20 value 148.725043
# iter  30 value 134.859552
# iter  40 value 108.835623
# iter  50 value 102.951094
# iter  60 value 90.276935
# iter  70 value 70.253407
# iter  80 value 49.377827
# iter  90 value 46.755403
# iter 100 value 46.543056
# final  value 46.543056
# stopped after 100 iterations
# # weights:  33
# initial  value 366.076364
# final  value 338.205804
# converged
# # weights:  97
# initial  value 456.804214
# final  value 338.207128
# converged
# # weights:  161
# initial  value 355.910839
# final  value 338.208071
# converged
# # weights:  33
# initial  value 431.995173
# final  value 338.671686
# converged
# # weights:  97
# initial  value 342.551960
# iter  10 value 253.680165
# iter  20 value 146.578513
# iter  30 value 146.287876
# iter  40 value 133.406659
# iter  50 value 131.362474
# final  value 131.362467
# converged
# # weights:  161
# initial  value 291.776376
# iter  10 value 144.147425
# iter  20 value 130.959146
# iter  30 value 126.627093
# iter  40 value 123.800459
# iter  50 value 123.688070
# iter  60 value 123.683316
# iter  70 value 123.682309
# final  value 123.682299
# converged
# # weights:  33
# initial  value 344.203317
# iter  10 value 338.686371
# final  value 338.685443
# converged
# # weights:  97
# initial  value 345.239987
# iter  10 value 279.532218
# iter  20 value 159.808691
# iter  30 value 121.191669
# iter  40 value 100.936370
# iter  50 value 58.418768
# iter  60 value 55.459762
# iter  70 value 55.285509
# iter  80 value 55.200905
# iter  90 value 54.370820
# iter 100 value 53.232027
# final  value 53.232027
# stopped after 100 iterations
# # weights:  161
# initial  value 679.107252
# iter  10 value 338.703064
# iter  20 value 263.970459
# iter  30 value 167.473572
# iter  40 value 126.098919
# iter  50 value 111.882314
# iter  60 value 71.397287
# iter  70 value 53.902819
# iter  80 value 48.248623
# iter  90 value 47.185613
# iter 100 value 45.819482
# final  value 45.819482
# stopped after 100 iterations
# # weights:  33
# initial  value 344.749103
# final  value 338.672106
# converged
# # weights:  97
# initial  value 341.854017
# final  value 338.673132
# converged
# # weights:  161
# initial  value 370.820140
# final  value 338.674251
# converged
# # weights:  33
# initial  value 398.991207
# iter  10 value 336.230075
# final  value 336.226687
# converged
# # weights:  97
# initial  value 363.427637
# final  value 338.205383
# converged
# # weights:  161
# initial  value 484.653152
# final  value 338.205383
# converged
# # weights:  33
# initial  value 362.273224
# iter  10 value 338.328595
# iter  20 value 330.690854
# iter  30 value 200.278848
# iter  40 value 141.008945
# iter  50 value 102.988229
# iter  60 value 83.978314
# iter  70 value 58.808696
# iter  80 value 56.870697
# iter  90 value 56.322552
# final  value 56.322541
# converged
# # weights:  97
# initial  value 662.794146
# iter  10 value 336.295239
# iter  20 value 188.655041
# iter  30 value 147.377058
# iter  40 value 135.939064
# iter  50 value 120.884769
# iter  60 value 76.379070
# iter  70 value 52.137654
# iter  80 value 49.182834
# iter  90 value 48.745840
# iter 100 value 48.411361
# final  value 48.411361
# stopped after 100 iterations
# # weights:  161
# initial  value 357.817116
# iter  10 value 335.967171
# iter  20 value 292.977809
# iter  30 value 225.752498
# iter  40 value 154.277392
# iter  50 value 118.136634
# iter  60 value 108.945038
# iter  70 value 82.254438
# iter  80 value 54.867913
# iter  90 value 49.836873
# iter 100 value 47.731510
# final  value 47.731510
# stopped after 100 iterations
# # weights:  33
# initial  value 371.220339
# final  value 338.206132
# converged
# # weights:  97
# initial  value 356.984441
# final  value 338.207088
# converged
# # weights:  161
# initial  value 343.807071
# final  value 338.208211
# converged
# # weights:  33
# initial  value 371.483961
# final  value 338.205383
# converged
# # weights:  97
# initial  value 370.401198
# final  value 338.205383
# converged
# # weights:  161
# initial  value 382.469768
# final  value 338.205383
# converged
# # weights:  33
# initial  value 436.869775
# iter  10 value 338.228739
# final  value 338.218999
# converged
# # weights:  97
# initial  value 357.798590
# iter  10 value 335.330993
# iter  20 value 283.717016
# iter  30 value 254.254751
# iter  40 value 197.439109
# iter  50 value 138.774330
# iter  60 value 102.722079
# iter  70 value 93.616005
# iter  80 value 66.460177
# iter  90 value 52.763389
# iter 100 value 49.283743
# final  value 49.283743
# stopped after 100 iterations
# # weights:  161
# initial  value 344.905626
# iter  10 value 303.583790
# iter  20 value 159.460346
# iter  30 value 124.745877
# iter  40 value 106.196460
# iter  50 value 102.471479
# iter  60 value 92.489280
# iter  70 value 63.028371
# iter  80 value 44.688699
# iter  90 value 42.345879
# iter 100 value 40.689699
# final  value 40.689699
# stopped after 100 iterations
# # weights:  33
# initial  value 339.178290
# final  value 338.205873
# converged
# # weights:  97
# initial  value 338.280766
# final  value 338.207026
# converged
# # weights:  161
# initial  value 427.482750
# final  value 338.207910
# converged
# # weights:  33
# initial  value 338.216115
# iter  10 value 273.612630
# iter  20 value 224.946908
# iter  30 value 155.365349
# iter  40 value 144.431096
# iter  50 value 144.429653
# iter  60 value 144.429089
# iter  70 value 143.769168
# iter  80 value 140.147875
# iter  90 value 138.099528
# iter 100 value 137.950162
# final  value 137.950162
# stopped after 100 iterations
# # weights:  97
# initial  value 360.356689
# final  value 338.205383
# converged
# # weights:  161
# initial  value 401.260272
# final  value 338.205383
# converged
# # weights:  33
# initial  value 395.061698
# iter  10 value 338.234512
# iter  20 value 302.203734
# iter  30 value 263.679644
# iter  40 value 167.599929
# iter  50 value 133.846982
# iter  60 value 61.161114
# iter  70 value 51.677826
# iter  80 value 50.816307
# final  value 50.815856
# converged
# # weights:  97
# initial  value 379.797355
# iter  10 value 334.722297
# iter  20 value 153.702411
# iter  30 value 62.032923
# iter  40 value 53.814888
# iter  50 value 50.302073
# iter  60 value 49.556646
# final  value 49.556641
# converged
# # weights:  161
# initial  value 374.219079
# iter  10 value 338.456818
# iter  20 value 297.751436
# iter  30 value 192.721503
# iter  40 value 182.304887
# iter  50 value 161.343133
# iter  60 value 141.530707
# iter  70 value 132.600041
# iter  80 value 117.477250
# iter  90 value 91.113435
# iter 100 value 70.647945
# final  value 70.647945
# stopped after 100 iterations
# # weights:  33
# initial  value 400.154705
# final  value 338.205951
# converged
# # weights:  97
# initial  value 331.287036
# iter  10 value 207.469060
# iter  20 value 147.948624
# iter  30 value 147.056804
# iter  40 value 147.046890
# iter  50 value 146.237045
# iter  60 value 143.897632
# iter  70 value 138.145490
# iter  80 value 132.102941
# iter  90 value 132.049768
# iter 100 value 129.912773
# final  value 129.912773
# stopped after 100 iterations
# # weights:  161
# initial  value 377.271047
# final  value 338.211826
# converged
# # weights:  33
# initial  value 351.234112
# final  value 337.217686
# converged
# # weights:  97
# initial  value 318.498214
# iter  10 value 168.454635
# iter  20 value 142.751739
# iter  30 value 142.274531
# iter  40 value 138.123124
# iter  50 value 131.462519
# iter  60 value 131.237074
# iter  70 value 131.236327
# iter  70 value 131.236327
# iter  70 value 131.236326
# final  value 131.236326
# converged
# # weights:  161
# initial  value 501.937214
# final  value 337.217685
# converged
# # weights:  33
# initial  value 337.857206
# iter  10 value 336.077889
# iter  20 value 217.110932
# iter  30 value 158.900568
# iter  40 value 152.522602
# iter  50 value 139.258781
# iter  60 value 132.024052
# iter  70 value 122.550315
# iter  80 value 64.009865
# iter  90 value 53.385474
# iter 100 value 53.204999
# final  value 53.204999
# stopped after 100 iterations
# # weights:  97
# initial  value 364.264209
# iter  10 value 337.318045
# iter  20 value 324.526894
# iter  30 value 209.990339
# iter  40 value 180.351266
# iter  50 value 147.444103
# iter  60 value 111.236408
# iter  70 value 92.013943
# iter  80 value 66.232161
# iter  90 value 49.513336
# iter 100 value 47.560318
# final  value 47.560318
# stopped after 100 iterations
# # weights:  161
# initial  value 340.823769
# iter  10 value 337.077099
# iter  20 value 292.603655
# iter  30 value 164.430729
# iter  40 value 81.491263
# iter  50 value 51.544307
# iter  60 value 51.105046
# iter  70 value 49.676032
# iter  80 value 48.076559
# iter  90 value 46.478785
# iter 100 value 46.469619
# final  value 46.469619
# stopped after 100 iterations
# # weights:  33
# initial  value 360.777619
# final  value 337.218183
# converged
# # weights:  97
# initial  value 352.464739
# final  value 337.219433
# converged
# # weights:  161
# initial  value 412.956426
# final  value 337.220506
# converged
# # weights:  33
# initial  value 497.883630
# final  value 338.205383
# converged
# # weights:  97
# initial  value 338.271318
# iter  10 value 337.243840
# iter  20 value 337.217713
# final  value 337.217690
# converged
# # weights:  161
# initial  value 334.936118
# iter  10 value 168.750292
# iter  20 value 132.710434
# iter  30 value 116.431736
# iter  40 value 109.152519
# iter  50 value 108.749466
# iter  60 value 108.282276
# iter  70 value 107.935785
# iter  80 value 107.912059
# iter  90 value 107.007298
# iter 100 value 105.083586
# final  value 105.083586
# stopped after 100 iterations
# # weights:  33
# initial  value 354.691767
# iter  10 value 337.083323
# iter  20 value 181.591667
# iter  30 value 171.132505
# iter  40 value 148.671315
# iter  50 value 113.047694
# iter  60 value 84.442374
# iter  70 value 54.587321
# iter  80 value 52.440627
# final  value 52.437638
# converged
# # weights:  97
# initial  value 347.296793
# iter  10 value 338.258431
# iter  20 value 329.692399
# iter  30 value 186.610153
# iter  40 value 138.793287
# iter  50 value 130.696910
# iter  60 value 118.991699
# iter  70 value 103.574264
# iter  80 value 66.234084
# iter  90 value 52.122517
# iter 100 value 50.811474
# final  value 50.811474
# stopped after 100 iterations
# # weights:  161
# initial  value 349.701601
# iter  10 value 337.413356
# iter  20 value 299.296007
# iter  30 value 196.833328
# iter  40 value 162.963143
# iter  50 value 148.571100
# iter  60 value 114.970957
# iter  70 value 107.082341
# iter  80 value 102.837323
# iter  90 value 99.434799
# iter 100 value 87.245697
# final  value 87.245697
# stopped after 100 iterations
# # weights:  33
# initial  value 345.924929
# final  value 338.205835
# converged
# # weights:  97
# initial  value 502.176416
# final  value 338.206785
# converged
# # weights:  161
# initial  value 558.981784
# iter  10 value 337.268349
# iter  20 value 230.493907
# iter  30 value 199.869981
# iter  40 value 197.265513
# iter  50 value 197.257066
# iter  60 value 197.255989
# iter  70 value 197.223091
# iter  80 value 195.421709
# iter  90 value 186.372511
# iter 100 value 140.553642
# final  value 140.553642
# stopped after 100 iterations
# # weights:  33
# initial  value 339.581943
# final  value 338.205383
# converged
# # weights:  97
# initial  value 390.225199
# final  value 338.205383
# converged
# # weights:  161
# initial  value 338.685472
# final  value 338.205383
# converged
# # weights:  33
# initial  value 348.334782
# iter  10 value 332.292953
# iter  20 value 190.154297
# iter  30 value 146.197547
# iter  40 value 140.536956
# iter  50 value 111.650958
# iter  60 value 85.527739
# iter  70 value 58.072220
# iter  80 value 51.534153
# final  value 51.532031
# converged
# # weights:  97
# initial  value 351.704806
# iter  10 value 337.989247
# iter  20 value 316.958454
# iter  30 value 310.807338
# iter  40 value 304.796493
# iter  50 value 171.108869
# iter  60 value 152.906496
# iter  70 value 116.660415
# iter  80 value 101.626075
# iter  90 value 100.810054
# iter 100 value 97.217444
# final  value 97.217444
# stopped after 100 iterations
# # weights:  161
# initial  value 417.964218
# iter  10 value 204.253717
# iter  20 value 146.268050
# iter  30 value 144.831223
# iter  40 value 124.401954
# iter  50 value 113.590797
# iter  60 value 108.760112
# iter  70 value 83.129213
# iter  80 value 61.392983
# iter  90 value 56.212390
# iter 100 value 45.376016
# final  value 45.376016
# stopped after 100 iterations
# # weights:  33
# initial  value 353.765930
# final  value 338.205831
# converged
# # weights:  97
# initial  value 408.407913
# final  value 338.207172
# converged
# # weights:  161
# initial  value 447.292168
# final  value 338.207794
# converged
# # weights:  33
# initial  value 359.569143
# final  value 338.671686
# converged
# # weights:  97
# initial  value 347.917436
# final  value 338.671686
# converged
# # weights:  161
# initial  value 393.486123
# final  value 338.671686
# converged
# # weights:  33
# initial  value 354.907539
# iter  10 value 338.689882
# iter  20 value 322.762706
# iter  30 value 311.568762
# iter  40 value 260.141712
# iter  50 value 154.715120
# iter  60 value 147.432559
# iter  70 value 132.146903
# iter  80 value 118.908029
# iter  90 value 101.049454
# iter 100 value 64.768936
# final  value 64.768936
# stopped after 100 iterations
# # weights:  97
# initial  value 433.197658
# iter  10 value 339.517397
# iter  20 value 206.663042
# iter  30 value 154.539120
# iter  40 value 143.450777
# iter  50 value 124.386817
# iter  60 value 99.441430
# iter  70 value 65.349152
# iter  80 value 59.874572
# iter  90 value 54.943401
# iter 100 value 54.714258
# final  value 54.714258
# stopped after 100 iterations
# # weights:  161
# initial  value 353.149764
# iter  10 value 339.043509
# iter  20 value 338.232188
# iter  30 value 336.821435
# iter  40 value 271.938849
# iter  50 value 165.492408
# iter  60 value 152.129299
# iter  70 value 135.311219
# iter  80 value 127.256905
# iter  90 value 117.552606
# iter 100 value 83.534314
# final  value 83.534314
# stopped after 100 iterations
# # weights:  33
# initial  value 351.566245
# iter  10 value 337.697348
# final  value 337.692845
# converged
# # weights:  97
# initial  value 400.753096
# final  value 338.673458
# converged
# # weights:  161
# initial  value 356.565045
# iter  10 value 337.693765
# final  value 337.692665
# converged
# # weights:  33
# initial  value 396.521957
# final  value 338.671686
# converged
# # weights:  97
# initial  value 355.186714
# final  value 338.671686
# converged
# # weights:  161
# initial  value 392.315724
# iter  10 value 335.844600
# iter  20 value 335.692980
# final  value 335.692787
# converged
# # weights:  33
# initial  value 339.502733
# iter  10 value 209.230112
# iter  20 value 133.721242
# iter  30 value 125.668228
# iter  40 value 106.970653
# iter  50 value 75.485681
# iter  60 value 56.174375
# iter  70 value 54.276968
# final  value 54.275353
# converged
# # weights:  97
# initial  value 455.975826
# iter  10 value 338.702066
# iter  20 value 170.271016
# iter  30 value 150.650566
# iter  40 value 127.660627
# iter  50 value 113.043054
# iter  60 value 70.099112
# iter  70 value 55.675269
# iter  80 value 53.096636
# iter  90 value 53.063141
# final  value 53.062661
# converged
# # weights:  161
# initial  value 378.386118
# iter  10 value 348.800464
# iter  20 value 348.288710
# iter  30 value 183.925951
# iter  40 value 154.261984
# iter  50 value 126.997407
# iter  60 value 100.986802
# iter  70 value 81.224224
# iter  80 value 74.309867
# iter  90 value 66.956105
# iter 100 value 49.000112
# final  value 49.000112
# stopped after 100 iterations
# # weights:  33
# initial  value 324.219081
# iter  10 value 145.175984
# iter  20 value 131.026773
# iter  30 value 125.631504
# iter  40 value 125.557508
# iter  50 value 125.545782
# iter  60 value 125.540291
# iter  70 value 125.533593
# iter  80 value 125.515908
# iter  90 value 124.551895
# iter 100 value 120.766008
# final  value 120.766008
# stopped after 100 iterations
# # weights:  97
# initial  value 347.887496
# final  value 338.673353
# converged
# # weights:  161
# initial  value 419.278487
# iter  10 value 342.527159
# iter  20 value 340.833868
# iter  30 value 259.356355
# iter  40 value 212.119265
# iter  50 value 179.082053
# iter  60 value 160.136930
# iter  70 value 155.402891
# iter  80 value 136.711654
# iter  90 value 133.483239
# iter 100 value 132.941400
# final  value 132.941400
# stopped after 100 iterations
# # weights:  33
# initial  value 376.805018
# final  value 338.671686
# converged
# # weights:  97
# initial  value 374.577445
# final  value 338.671686
# converged
# # weights:  161
# initial  value 358.547818
# final  value 338.671686
# converged
# # weights:  33
# initial  value 348.648347
# iter  10 value 337.239336
# iter  20 value 269.635092
# iter  30 value 227.429057
# iter  40 value 162.893149
# iter  50 value 133.156837
# iter  60 value 124.090258
# iter  70 value 122.484776
# iter  80 value 122.458571
# final  value 122.457784
# converged
# # weights:  97
# initial  value 354.212188
# iter  10 value 337.858460
# iter  20 value 175.625890
# iter  30 value 128.890998
# iter  40 value 114.213935
# iter  50 value 104.244747
# iter  60 value 95.010341
# iter  70 value 74.212673
# iter  80 value 51.775594
# iter  90 value 49.765526
# iter 100 value 49.751003
# final  value 49.751003
# stopped after 100 iterations
# # weights:  161
# initial  value 345.155787
# iter  10 value 338.690099
# iter  20 value 337.215584
# iter  30 value 161.050279
# iter  40 value 141.575117
# iter  50 value 133.429331
# iter  60 value 103.612791
# iter  70 value 89.727355
# iter  80 value 78.867325
# iter  90 value 67.332798
# iter 100 value 50.071268
# final  value 50.071268
# stopped after 100 iterations
# # weights:  33
# initial  value 350.567922
# final  value 338.672193
# converged
# # weights:  97
# initial  value 380.589502
# final  value 338.679852
# converged
# # weights:  161
# initial  value 435.897721
# final  value 338.675813
# converged
# # weights:  33
# initial  value 379.603116
# final  value 337.217686
# converged
# # weights:  97
# initial  value 337.930990
# final  value 337.217686
# converged
# # weights:  161
# initial  value 392.660435
# iter  10 value 206.381350
# iter  20 value 186.350271
# iter  30 value 178.241176
# final  value 178.240439
# converged
# # weights:  33
# initial  value 354.894891
# iter  10 value 337.232018
# iter  20 value 269.058279
# iter  30 value 251.394885
# iter  40 value 248.339764
# iter  50 value 150.298496
# iter  60 value 117.179121
# iter  70 value 78.902564
# iter  80 value 54.577214
# iter  90 value 54.168725
# final  value 54.168680
# converged
# # weights:  97
# initial  value 343.617020
# iter  10 value 303.544356
# iter  20 value 181.687287
# iter  30 value 135.280738
# iter  40 value 94.936503
# iter  50 value 73.108511
# iter  60 value 60.736923
# iter  70 value 53.926487
# iter  80 value 51.591486
# iter  90 value 45.773632
# iter 100 value 39.807832
# final  value 39.807832
# stopped after 100 iterations
# # weights:  161
# initial  value 496.207475
# iter  10 value 276.823458
# iter  20 value 251.202475
# iter  30 value 202.752425
# iter  40 value 164.195257
# iter  50 value 117.197808
# iter  60 value 104.258688
# iter  70 value 94.605724
# iter  80 value 81.670209
# iter  90 value 64.072025
# iter 100 value 59.404035
# final  value 59.404035
# stopped after 100 iterations
# # weights:  33
# initial  value 409.642188
# final  value 337.218272
# converged
# # weights:  97
# initial  value 387.471525
# final  value 337.220159
# converged
# # weights:  161
# initial  value 341.018536
# iter  10 value 198.423653
# iter  20 value 192.325359
# iter  30 value 170.184841
# iter  40 value 151.027312
# iter  50 value 150.515191
# iter  60 value 150.510552
# iter  70 value 150.502304
# iter  80 value 148.501319
# iter  90 value 148.463903
# iter 100 value 148.463242
# final  value 148.463242
# stopped after 100 iterations
# # weights:  33
# initial  value 342.367980
# iter  10 value 151.042784
# iter  20 value 147.630681
# iter  30 value 147.615984
# iter  40 value 145.404413
# iter  50 value 143.393938
# iter  60 value 142.838279
# iter  70 value 134.431626
# iter  80 value 103.973865
# iter  90 value 100.271530
# iter 100 value 99.178327
# final  value 99.178327
# stopped after 100 iterations
# # weights:  97
# initial  value 472.806476
# iter  10 value 135.686504
# iter  20 value 122.329560
# iter  30 value 116.079261
# iter  40 value 113.387074
# iter  50 value 112.712411
# iter  60 value 112.647848
# iter  70 value 112.614074
# iter  80 value 112.613368
# final  value 112.613352
# converged
# # weights:  161
# initial  value 401.775283
# final  value 338.205383
# converged
# # weights:  33
# initial  value 366.893642
# iter  10 value 338.003558
# iter  20 value 143.410804
# iter  30 value 137.190737
# iter  40 value 108.323079
# iter  50 value 68.005496
# iter  60 value 54.622167
# iter  70 value 54.388018
# final  value 54.387983
# converged
# # weights:  97
# initial  value 365.653473
# iter  10 value 338.281031
# iter  20 value 338.223023
# iter  30 value 331.594220
# iter  40 value 194.451668
# iter  50 value 150.486173
# iter  60 value 144.946674
# iter  70 value 138.927079
# iter  80 value 126.370887
# iter  90 value 117.103763
# iter 100 value 99.643507
# final  value 99.643507
# stopped after 100 iterations
# # weights:  161
# initial  value 475.458417
# iter  10 value 338.270026
# iter  20 value 338.205684
# iter  30 value 323.459150
# iter  40 value 314.607006
# iter  50 value 158.503627
# iter  60 value 150.709554
# iter  70 value 135.583071
# iter  80 value 124.705426
# iter  90 value 119.097140
# iter 100 value 110.541058
# final  value 110.541058
# stopped after 100 iterations
# # weights:  33
# initial  value 339.744334
# final  value 338.205742
# converged
# # weights:  97
# initial  value 356.542660
# final  value 338.207002
# converged
# # weights:  161
# initial  value 345.873753
# iter  10 value 336.727880
# iter  20 value 336.241034
# iter  30 value 336.240743
# iter  40 value 336.237582
# iter  50 value 304.975994
# iter  60 value 244.663101
# iter  70 value 146.998891
# iter  80 value 51.305771
# iter  90 value 40.603272
# iter 100 value 34.710772
# final  value 34.710772
# stopped after 100 iterations
# # weights:  33
# initial  value 396.060622
# final  value 337.217686
# converged
# # weights:  97
# initial  value 326.306892
# iter  10 value 219.993336
# iter  20 value 159.071734
# iter  30 value 155.030460
# iter  40 value 148.654678
# iter  50 value 148.624367
# final  value 148.624141
# converged
# # weights:  161
# initial  value 439.322368
# final  value 337.217686
# converged
# # weights:  33
# initial  value 343.236665
# iter  10 value 337.244082
# iter  20 value 337.231579
# iter  20 value 337.231577
# iter  20 value 337.231577
# final  value 337.231577
# converged
# # weights:  97
# initial  value 339.225657
# iter  10 value 297.469537
# iter  20 value 205.379613
# iter  30 value 157.471638
# iter  40 value 140.139405
# iter  50 value 105.355320
# iter  60 value 84.405425
# iter  70 value 56.330669
# iter  80 value 50.702615
# iter  90 value 48.902502
# iter 100 value 42.751098
# final  value 42.751098
# stopped after 100 iterations
# # weights:  161
# initial  value 346.229463
# iter  10 value 231.279237
# iter  20 value 148.046166
# iter  30 value 132.262577
# iter  40 value 119.324524
# iter  50 value 84.686392
# iter  60 value 69.266122
# iter  70 value 58.208756
# iter  80 value 51.545884
# iter  90 value 44.821356
# iter 100 value 44.161829
# final  value 44.161829
# stopped after 100 iterations
# # weights:  33
# initial  value 351.444633
# final  value 337.218241
# converged
# # weights:  97
# initial  value 511.754032
# final  value 337.219370
# converged
# # weights:  161
# initial  value 358.378156
# final  value 337.220375
# converged
# # weights:  33
# initial  value 338.321043
# final  value 338.205383
# converged
# # weights:  97
# initial  value 356.927133
# final  value 338.205383
# converged
# # weights:  161
# initial  value 379.539153
# final  value 338.205383
# converged
# # weights:  33
# initial  value 422.280949
# iter  10 value 338.219207
# final  value 338.218978
# converged
# # weights:  97
# initial  value 370.617529
# iter  10 value 350.960627
# iter  20 value 338.285388
# iter  30 value 284.473062
# iter  40 value 243.874543
# iter  50 value 150.872331
# iter  60 value 140.715694
# iter  70 value 94.739234
# iter  80 value 71.919922
# iter  90 value 61.873931
# iter 100 value 53.042155
# final  value 53.042155
# stopped after 100 iterations
# # weights:  161
# initial  value 352.084180
# iter  10 value 160.547409
# iter  20 value 124.957344
# iter  30 value 108.028033
# iter  40 value 102.892760
# iter  50 value 83.764769
# iter  60 value 74.400042
# iter  70 value 67.287451
# iter  80 value 62.054674
# iter  90 value 52.759992
# iter 100 value 41.910039
# final  value 41.910039
# stopped after 100 iterations
# # weights:  33
# initial  value 338.837704
# final  value 338.206069
# converged
# # weights:  97
# initial  value 353.605300
# final  value 338.207188
# converged
# # weights:  161
# initial  value 338.397328
# final  value 338.207697
# converged
# # weights:  33
# initial  value 369.168314
# final  value 338.205383
# converged
# # weights:  97
# initial  value 359.217199
# iter  10 value 330.337033
# iter  20 value 330.209993
# final  value 330.209873
# converged
# # weights:  161
# initial  value 373.682674
# final  value 338.205383
# converged
# # weights:  33
# initial  value 343.682078
# iter  10 value 338.278025
# iter  20 value 338.219000
# iter  20 value 338.218999
# iter  20 value 338.218999
# final  value 338.218999
# converged
# # weights:  97
# initial  value 537.719119
# iter  10 value 302.945833
# iter  20 value 189.471688
# iter  30 value 144.361648
# iter  40 value 136.053005
# iter  50 value 127.173811
# iter  60 value 95.188427
# iter  70 value 59.058748
# iter  80 value 45.854564
# iter  90 value 44.087779
# iter 100 value 43.835701
# final  value 43.835701
# stopped after 100 iterations
# # weights:  161
# initial  value 477.174281
# iter  10 value 292.684419
# iter  20 value 163.932559
# iter  30 value 149.013394
# iter  40 value 120.016959
# iter  50 value 96.693579
# iter  60 value 80.767181
# iter  70 value 69.454398
# iter  80 value 52.602053
# iter  90 value 50.432048
# iter 100 value 47.996711
# final  value 47.996711
# stopped after 100 iterations
# # weights:  33
# initial  value 346.444763
# final  value 338.205922
# converged
# # weights:  97
# initial  value 347.361027
# final  value 338.207029
# converged
# # weights:  161
# initial  value 350.864322
# iter  10 value 161.886238
# iter  20 value 147.962189
# iter  30 value 146.760773
# iter  40 value 139.945769
# iter  50 value 132.438197
# iter  60 value 132.426672
# iter  60 value 132.426671
# iter  70 value 132.426153
# iter  80 value 132.397621
# iter  90 value 129.272687
# iter 100 value 123.049041
# final  value 123.049041
# stopped after 100 iterations
# # weights:  33
# initial  value 334.220089
# iter  10 value 180.571013
# iter  20 value 149.036573
# iter  30 value 145.305194
# iter  40 value 144.591044
# iter  50 value 136.921568
# iter  60 value 134.002157
# iter  70 value 131.521979
# iter  80 value 131.188800
# iter  90 value 130.432111
# iter 100 value 128.967380
# final  value 128.967380
# stopped after 100 iterations
# # weights:  97
# initial  value 340.520296
# iter  10 value 175.797700
# iter  20 value 150.109103
# iter  30 value 147.637205
# iter  40 value 145.252116
# iter  50 value 145.244737
# final  value 145.244666
# converged
# # weights:  161
# initial  value 391.425845
# iter  10 value 226.602617
# iter  20 value 141.201198
# iter  30 value 120.205029
# iter  40 value 114.616260
# iter  50 value 109.627278
# iter  60 value 90.153493
# iter  70 value 62.369878
# iter  80 value 35.846339
# iter  90 value 22.920898
# iter 100 value 16.074284
# final  value 16.074284
# stopped after 100 iterations
# # weights:  33
# initial  value 340.412008
# iter  10 value 336.783712
# iter  20 value 266.957268
# iter  30 value 163.199818
# iter  40 value 146.047413
# iter  50 value 141.444979
# iter  60 value 122.220846
# iter  70 value 68.748311
# iter  80 value 54.266418
# iter  90 value 53.956196
# final  value 53.956187
# converged
# # weights:  97
# initial  value 343.611282
# iter  10 value 337.283943
# iter  20 value 285.992186
# iter  30 value 162.002883
# iter  40 value 117.463816
# iter  50 value 106.931248
# iter  60 value 67.956280
# iter  70 value 48.697811
# iter  80 value 46.810297
# iter  90 value 46.494546
# iter 100 value 43.300821
# final  value 43.300821
# stopped after 100 iterations
# # weights:  161
# initial  value 445.494128
# iter  10 value 337.773752
# iter  20 value 337.499096
# iter  30 value 336.670370
# iter  40 value 300.927270
# iter  50 value 273.985339
# iter  60 value 158.963155
# iter  70 value 115.281697
# iter  80 value 101.273054
# iter  90 value 88.478160
# iter 100 value 58.847654
# final  value 58.847654
# stopped after 100 iterations
# # weights:  33
# initial  value 425.777131
# final  value 337.682536
# converged
# # weights:  97
# initial  value 376.210385
# final  value 337.683560
# converged
# # weights:  161
# initial  value 346.237127
# iter  10 value 273.425278
# iter  20 value 233.779596
# iter  30 value 216.237209
# iter  40 value 216.233154
# iter  50 value 186.141010
# iter  60 value 185.216326
# iter  70 value 185.198124
# iter  80 value 185.178907
# iter  90 value 185.178179
# iter 100 value 161.988728
# final  value 161.988728
# stopped after 100 iterations
# # weights:  33
# initial  value 353.579307
# final  value 338.671686
# converged
# # weights:  97
# initial  value 343.008258
# final  value 338.671686
# converged
# # weights:  161
# initial  value 360.822890
# final  value 338.671686
# converged
# # weights:  33
# initial  value 390.706795
# iter  10 value 319.787420
# iter  20 value 240.737870
# iter  30 value 159.499795
# iter  40 value 151.604860
# iter  50 value 139.378654
# iter  60 value 113.900836
# iter  70 value 104.482711
# iter  80 value 61.145661
# iter  90 value 58.513788
# iter 100 value 57.126646
# final  value 57.126646
# stopped after 100 iterations
# # weights:  97
# initial  value 357.449915
# iter  10 value 318.533903
# iter  20 value 231.142535
# iter  30 value 195.543400
# iter  40 value 116.876467
# iter  50 value 62.753938
# iter  60 value 59.050944
# iter  70 value 57.135228
# iter  80 value 55.960222
# iter  90 value 55.784748
# iter 100 value 54.509294
# final  value 54.509294
# stopped after 100 iterations
# # weights:  161
# initial  value 341.872369
# iter  10 value 336.913178
# iter  20 value 303.582587
# iter  30 value 141.841014
# iter  40 value 134.733071
# iter  50 value 133.169298
# iter  60 value 122.426239
# iter  70 value 110.781272
# iter  80 value 84.252793
# iter  90 value 74.514992
# iter 100 value 60.009490
# final  value 60.009490
# stopped after 100 iterations
# # weights:  33
# initial  value 387.831733
# final  value 338.672091
# converged
# # weights:  97
# initial  value 355.771136
# final  value 338.674351
# converged
# # weights:  161
# initial  value 482.891749
# final  value 338.676060
# converged
# # weights:  33
# initial  value 487.865699
# final  value 338.205383
# converged
# # weights:  97
# initial  value 340.039925
# final  value 338.205383
# converged
# # weights:  161
# initial  value 321.631623
# iter  10 value 138.963242
# iter  20 value 129.605498
# iter  30 value 120.944485
# iter  40 value 116.097676
# iter  50 value 116.035286
# iter  60 value 116.027751
# final  value 116.027743
# converged
# # weights:  33
# initial  value 431.961108
# iter  10 value 338.567205
# iter  20 value 338.219833
# final  value 338.218999
# converged
# # weights:  97
# initial  value 342.134899
# iter  10 value 220.881019
# iter  20 value 138.877518
# iter  30 value 123.932350
# iter  40 value 120.342716
# iter  50 value 118.253836
# iter  60 value 95.074924
# iter  70 value 75.180473
# iter  80 value 53.815846
# iter  90 value 48.956165
# iter 100 value 48.669026
# final  value 48.669026
# stopped after 100 iterations
# # weights:  161
# initial  value 383.883160
# iter  10 value 337.304590
# iter  20 value 162.193803
# iter  30 value 144.952555
# iter  40 value 140.866859
# iter  50 value 134.127725
# iter  60 value 115.764832
# iter  70 value 85.835077
# iter  80 value 59.862691
# iter  90 value 49.932887
# iter 100 value 48.997364
# final  value 48.997364
# stopped after 100 iterations
# # weights:  33
# initial  value 402.416420
# final  value 338.205949
# converged
# # weights:  97
# initial  value 352.930083
# final  value 338.207415
# converged
# # weights:  161
# initial  value 352.779705
# iter  10 value 179.826197
# iter  20 value 140.166312
# iter  30 value 137.793810
# iter  40 value 118.443107
# iter  50 value 103.678264
# iter  60 value 102.298141
# iter  70 value 102.228054
# iter  80 value 102.222046
# iter  90 value 102.218482
# iter 100 value 102.216628
# final  value 102.216628
# stopped after 100 iterations
# # weights:  33
# initial  value 348.278258
# final  value 338.205383
# converged
# # weights:  97
# initial  value 376.807636
# iter  10 value 287.779515
# iter  20 value 224.479718
# iter  30 value 197.758288
# iter  40 value 97.067966
# iter  50 value 88.350112
# iter  60 value 86.853913
# iter  70 value 67.360748
# iter  80 value 56.847793
# iter  90 value 52.105177
# iter 100 value 49.320522
# final  value 49.320522
# stopped after 100 iterations
# # weights:  161
# initial  value 345.818361
# iter  10 value 248.722463
# iter  20 value 185.535073
# final  value 180.055072
# converged
# # weights:  33
# initial  value 417.340365
# iter  10 value 338.219353
# final  value 338.218995
# converged
# # weights:  97
# initial  value 469.023116
# iter  10 value 338.040927
# iter  20 value 312.712437
# iter  30 value 158.592850
# iter  40 value 123.261640
# iter  50 value 83.652537
# iter  60 value 67.747336
# iter  70 value 59.094042
# iter  80 value 51.808586
# iter  90 value 48.075303
# iter 100 value 46.078032
# final  value 46.078032
# stopped after 100 iterations
# # weights:  161
# initial  value 466.826651
# iter  10 value 338.667913
# iter  20 value 315.679234
# iter  30 value 190.735681
# iter  40 value 136.441319
# iter  50 value 122.799987
# iter  60 value 113.946030
# iter  70 value 102.556223
# iter  80 value 64.253222
# iter  90 value 47.355868
# iter 100 value 44.669499
# final  value 44.669499
# stopped after 100 iterations
# # weights:  33
# initial  value 428.816710
# final  value 338.205991
# converged
# # weights:  97
# initial  value 396.722077
# final  value 338.206878
# converged
# # weights:  161
# initial  value 434.182943
# final  value 338.207789
# converged
# # weights:  33
# initial  value 346.152142
# final  value 338.671686
# converged
# # weights:  97
# initial  value 343.679264
# final  value 338.671686
# converged
# # weights:  161
# initial  value 370.238487
# iter  10 value 237.008322
# iter  20 value 158.720460
# iter  30 value 158.042095
# iter  40 value 158.040858
# iter  50 value 158.040329
# iter  60 value 154.407198
# iter  70 value 147.817164
# iter  80 value 143.944018
# iter  90 value 142.810059
# iter 100 value 141.600955
# final  value 141.600955
# stopped after 100 iterations
# # weights:  33
# initial  value 341.655746
# final  value 338.685469
# converged
# # weights:  97
# initial  value 372.427901
# iter  10 value 200.158577
# iter  20 value 171.093158
# iter  30 value 122.271121
# iter  40 value 116.784648
# iter  50 value 94.312267
# iter  60 value 88.447443
# iter  70 value 83.076185
# iter  80 value 73.994176
# iter  90 value 68.829572
# iter 100 value 59.329189
# final  value 59.329189
# stopped after 100 iterations
# # weights:  161
# initial  value 345.148076
# iter  10 value 176.238785
# iter  20 value 143.946404
# iter  30 value 109.756716
# iter  40 value 104.225392
# iter  50 value 94.681046
# iter  60 value 80.291897
# iter  70 value 64.678736
# iter  80 value 57.704128
# iter  90 value 47.970957
# iter 100 value 39.477281
# final  value 39.477281
# stopped after 100 iterations
# # weights:  33
# initial  value 428.683045
# final  value 338.672638
# converged
# # weights:  97
# initial  value 491.219870
# final  value 338.673487
# converged
# # weights:  161
# initial  value 338.857861
# final  value 338.674110
# converged
# # weights:  33
# initial  value 467.000517
# final  value 338.205383
# converged
# # weights:  97
# initial  value 402.676410
# iter  10 value 167.108378
# iter  20 value 137.958227
# iter  30 value 129.740317
# iter  40 value 126.659029
# iter  50 value 126.648050
# iter  60 value 126.647866
# final  value 126.647761
# converged
# # weights:  161
# initial  value 468.968856
# final  value 338.205383
# converged
# # weights:  33
# initial  value 472.514322
# iter  10 value 338.219022
# final  value 338.218998
# converged
# # weights:  97
# initial  value 431.695039
# iter  10 value 325.547594
# iter  20 value 215.039004
# iter  30 value 204.259720
# iter  40 value 150.489410
# iter  50 value 128.860903
# iter  60 value 89.622761
# iter  70 value 69.577048
# iter  80 value 46.288356
# iter  90 value 39.599779
# iter 100 value 37.645654
# final  value 37.645654
# stopped after 100 iterations
# # weights:  161
# initial  value 352.441834
# iter  10 value 188.928655
# iter  20 value 153.740946
# iter  30 value 119.850121
# iter  40 value 102.923056
# iter  50 value 80.217080
# iter  60 value 58.129146
# iter  70 value 51.508105
# iter  80 value 41.898837
# iter  90 value 37.796874
# iter 100 value 37.355211
# final  value 37.355211
# stopped after 100 iterations
# # weights:  33
# initial  value 419.790322
# final  value 338.205894
# converged
# # weights:  97
# initial  value 366.567313
# final  value 338.206950
# converged
# # weights:  161
# initial  value 350.036224
# final  value 338.208133
# converged
# # weights:  161
# initial  value 413.843786
# iter  10 value 375.590244
# iter  20 value 332.185254
# iter  30 value 166.618724
# iter  40 value 153.174121
# iter  50 value 150.304408
# iter  60 value 133.948086
# iter  70 value 114.758288
# iter  80 value 80.239821
# iter  90 value 60.300768
# iter 100 value 52.158844
# final  value 52.158844
# stopped after 100 iterations

# %% [markdown]
# ###  Mostrem les característiques del model

# %%
models
# Out:
# $nnet
# Neural Network
#
# 569 samples
#  30 predictor
#   2 classes: 'B', 'M'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 3 times)
# Summary of sample sizes: 512, 511, 512, 512, 513, 512, ...
# Resampling results across tuning parameters:
#
#   size  decay  Accuracy   Kappa
#   1     0e+00  0.6747908  0.13406377
#   1     1e-04  0.6357557  0.02400000
#   1     1e-01  0.8125828  0.50874448
#   3     0e+00  0.7126264  0.24124798
#   3     1e-04  0.6461358  0.05232068
#   3     1e-01  0.9267818  0.82891238
#   5     0e+00  0.7134982  0.24411617
#   5     1e-04  0.7368057  0.30781970
#   5     1e-01  0.9436774  0.87747716
#
# Accuracy was used to select the optimal model using the largest value.
# The final values used for the model were size = 5 and decay = 0.1.
#
# $rpart
# CART
#
# 569 samples
#  30 predictor
#   2 classes: 'B', 'M'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 3 times)
# Summary of sample sizes: 512, 511, 512, 512, 513, 512, ...
# Resampling results across tuning parameters:
#
#   cp           Accuracy   Kappa
#   0.004716981  0.9284296  0.8463765
#   0.049528302  0.9103092  0.8092447
#   0.792452830  0.7855479  0.4623542
#
# Accuracy was used to select the optimal model using the largest value.
# The final value used for the model was cp = 0.004716981.
#
# $C5.0
# C5.0
#
# 569 samples
#  30 predictor
#   2 classes: 'B', 'M'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 3 times)
# Summary of sample sizes: 512, 511, 512, 512, 513, 512, ...
# Resampling results across tuning parameters:
#
#   model  winnow  trials  Accuracy   Kappa
#   rules  FALSE    1      0.9361262  0.8630205
#   rules  FALSE   10      0.9612861  0.9163152
#   rules  FALSE   20      0.9636465  0.9215785
#   rules   TRUE    1      0.9454736  0.8833763
#   rules   TRUE   10      0.9513435  0.8954714
#   rules   TRUE   20      0.9518869  0.8966390
#   tree   FALSE    1      0.9343513  0.8593503
#   tree   FALSE   10      0.9566272  0.9067362
#   tree   FALSE   20      0.9584025  0.9107489
#   tree    TRUE    1      0.9425183  0.8770547
#   tree    TRUE   10      0.9478650  0.8881915
#   tree    TRUE   20      0.9501527  0.8929753
#
# Accuracy was used to select the optimal model using the largest value.
# The final values used for the model were trials = 20, model = rules and
#  winnow = FALSE.
#
# $knn
# k-Nearest Neighbors
#
# 569 samples
#  30 predictor
#   2 classes: 'B', 'M'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 3 times)
# Summary of sample sizes: 512, 511, 512, 512, 513, 512, ...
# Resampling results across tuning parameters:
#
#   k  Accuracy   Kappa
#   5  0.9297032  0.8476087
#   7  0.9320114  0.8531854
#   9  0.9314165  0.8514653
#
# Accuracy was used to select the optimal model using the largest value.
# The final value used for the model was k = 7.
#
# $svmRadial
# Support Vector Machines with Radial Basis Function Kernel
#
# 569 samples
#  30 predictor
#   2 classes: 'B', 'M'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 3 times)
# Summary of sample sizes: 512, 511, 512, 512, 513, 512, ...
# Resampling results across tuning parameters:
#
#   C     Accuracy   Kappa
#   0.25  0.9595724  0.9132867
#   0.50  0.9683764  0.9324672
#   1.00  0.9719061  0.9400755
#
# Tuning parameter 'sigma' was held constant at a value of 0.0411333
# Accuracy was used to select the optimal model using the largest value.
# The final values used for the model were sigma = 0.0411333 and C = 1.
#
# attr(,"class")
# [1] "caretList"

# %%
results.N0 <- resamples(models)
summary(results.N0)
# Out:
# Call:
# summary.resamples(object = results.N0)
#
# Models: nnet, rpart, C5.0, knn, svmRadial
# Number of resamples: 30
#
# Accuracy
#                Min.   1st Qu.    Median      Mean   3rd Qu.      Max. NA's
# nnet      0.8214286 0.9310345 0.9562808 0.9436774 0.9649123 0.9824561    0
# rpart     0.8571429 0.9122807 0.9298246 0.9284296 0.9473684 1.0000000    0
# C5.0      0.8928571 0.9473684 0.9649123 0.9636465 0.9824561 1.0000000    0
# knn       0.8928571 0.9174877 0.9298246 0.9320114 0.9473684 0.9824561    0
# svmRadial 0.9298246 0.9644424 0.9822995 0.9719061 0.9824561 1.0000000    0
#
# Kappa
#                Min.   1st Qu.    Median      Mean   3rd Qu.      Max. NA's
# nnet      0.5789474 0.8521947 0.9061103 0.8774772 0.9246032 0.9626719    0
# rpart     0.6831683 0.8142586 0.8500530 0.8463765 0.8874547 1.0000000    0
# C5.0      0.7623762 0.8880157 0.9234432 0.9215785 0.9621791 1.0000000    0
# knn       0.7623762 0.8246362 0.8498368 0.8531854 0.8857108 0.9619238    0
# svmRadial 0.8492063 0.9230769 0.9619238 0.9400755 0.9631406 1.0000000    0

# %%
dotplot(results.N0)
# Out:
# plot without title

# %% [markdown]
# ### Revisem la correlació entre els diferents models

# %%
modelCor(results.N0)
splom(results.N0)
# Out:
#           nnet        rpart     C5.0      knn        svmRadial
# nnet       1.00000000 0.2971017 0.1288437 0.05219935 -0.1431716
# rpart      0.29710165 1.0000000 0.3708069 0.20747662  0.3180995
# C5.0       0.12884375 0.3708069 1.0000000 0.23719576  0.5553513
# knn        0.05219935 0.2074766 0.2371958 1.00000000  0.1313860
# svmRadial -0.14317156 0.3180995 0.5553513 0.13138599  1.0000000
# plot without title

# %% [markdown]
# ### Construcció del model final

# %% [markdown]
# ### Paràmetres de construcció

# %%
stackControl <- trainControl(method="repeatedcv", number=10, repeats=3, savePredictions=TRUE, classProbs=TRUE)

# %% [markdown]
# ### Creació del model

# %%
N1.rf <- caretStack(models, method="rf", metric="Accuracy", trControl=stackControl)

# %% [markdown]
# ###  Mostrem les característiques del model final

# %%
print(N1.rf)
# Out:
# A rf ensemble of 2 base models: nnet, rpart, C5.0, knn, svmRadial
#
# Ensemble results:
# Random Forest
#
# 1707 samples
#    5 predictor
#    2 classes: 'B', 'M'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 3 times)
# Summary of sample sizes: 1535, 1537, 1536, 1537, 1537, 1537, ...
# Resampling results across tuning parameters:
#
#   mtry  Accuracy   Kappa
#   2     0.9851633  0.9681497
#   3     0.9851621  0.9681506
#   5     0.9837942  0.9652048
#
# Accuracy was used to select the optimal model using the largest value.
# The final value used for the model was mtry = 2.

# %% [markdown]
# <!--Footer-->
#  <div style="background: #333333;padding: 35px 0px;margin-top: 25px;">
#     <div class="row">
#      <div class="col-sm-12">
#         <img src="http://materials.cv.uoc.edu/cdocent/common/img/logo-uoc-bottom.png" alt="Logo UOC" class="img-responsive" style="margin: 0 auto; display: block;">
#     </div>
# </div>
# </div>
# <!--/Footer-->
